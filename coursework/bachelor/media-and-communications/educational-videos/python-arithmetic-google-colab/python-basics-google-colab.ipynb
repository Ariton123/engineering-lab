# %%
#променливатa x има вредност 2, а y има вредност 4
x = 2
y = 4

# %%
#Вака се печати било каков текст на екран!
print("Hello world!")
# Out:
# Hello world!

# %%
#Вака се собираат два броја, може да напишеме и директно 2+4 и ќе ни врати резултат 6
x+y
# Out:
# 6

# %%
#Истото важи како и за собирање
x-y
# Out:
# -2

# %%
#Множење на две променливи
x*y
# Out:
# 8

# %%
#Делење
y/x
# Out:
# 2.0

# %%
#складирање на збирот во нова променлива result
result = x + y

# %%
#ако ја испечатиме на екран ќе добиеме 6, т.е збирот од x+y!
result
# Out:
# 6
